# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Load the CSV files
event_details_path = 'ufc_event_details.csv'
fight_results_path = 'ufc_fight_results.csv'
fight_stats_path = 'ufc_fight_stats.csv'

# %%
# create dataframes
event_details_df = pd.read_csv(event_details_path)
fight_results_df = pd.read_csv(fight_results_path)
fight_stats_df = pd.read_csv(fight_stats_path)

# %%
# convert 'event_date' to datetime format in the event details DataFrame
event_details_df['DATE'] = pd.to_datetime(event_details_df['DATE'])

# %%
# define a function to filter events based on a date range
def filter_events_by_date_range(df, start_date, end_date):
    mask = (df['DATE'] >= start_date) & (df['DATE'] <= end_date)
    return df.loc[mask]

# %%
# input date range for filtering
start_date = '2020-01-01'
end_date = '2022-12-31'

# %%
#filter the events based on the date range
filter_events_df = filter_events_by_date_range(event_details_df, start_date, end_date)
print('events in date range: ', filter_events_df)
# Out:
# events in date range:                                           EVENT  \
# 62   UFC Fight Night: Cannonier vs. Strickland
# 63            UFC 282: Blachowicz vs. Ankalaev
# 64       UFC Fight Night: Thompson vs. Holland
# 65     UFC Fight Night: Nzechukwu vs. Cutelaba
# 66               UFC 281: Adesanya vs. Pereira
# ..                                         ...
# 183         UFC Fight Night: Felder vs. Hooker
# 184   UFC Fight Night: Anderson vs. Blachowicz
# 185                   UFC 247: Jones vs. Reyes
# 186    UFC Fight Night: Blaydes vs. Dos Santos
# 187               UFC 246: McGregor vs. Cowboy
#
#                                                    URL       DATE  \
# 62   http://ufcstats.com/event-details/56ec58954158... 2022-12-17
# 63   http://ufcstats.com/event-details/f65a0eb902f9... 2022-12-10
# 64   http://ufcstats.com/event-details/b23388ff8ac6... 2022-12-03
# 65   http://ufcstats.com/event-details/012fc7cd0779... 2022-11-19
# 66   http://ufcstats.com/event-details/b3b6e80b7d5f... 2022-11-12
# ..                                                 ...        ...
# 183  http://ufcstats.com/event-details/33b2f68ef952... 2020-02-22
# 184  http://ufcstats.com/event-details/5df17b362014... 2020-02-15
# 185  http://ufcstats.com/event-details/b26d3e3746fb... 2020-02-08
# 186  http://ufcstats.com/event-details/44aa652b181b... 2020-01-25
# 187  http://ufcstats.com/event-details/0c1773639c79... 2020-01-18
#
#                          LOCATION
# 62         Las Vegas, Nevada, USA
# 63         Las Vegas, Nevada, USA
# 64          Orlando, Florida, USA
# 65         Las Vegas, Nevada, USA
# 66   New York City, New York, USA
# ..                            ...
# 183         Auckland, New Zealand
# 184   Rio Rancho, New Mexico, USA
# 185           Houston, Texas, USA
# 186  Raleigh, North Carolina, USA
# 187        Las Vegas, Nevada, USA
#
# [126 rows x 4 columns]

# %%
# extract the event names
filtered_event_names = filter_events_df['EVENT'].tolist()
print('filtered_event_names: ', filtered_event_names)
# Out:
liveira vs. Chandler', 'UFC Fight Night: Rodriguez vs. Waterson', 'UFC Fight Night: Reyes vs. Prochazka', 'UFC 261: Usman vs. Masvidal 2', 'UFC Fight Night: Whittaker vs. Gastelum', 'UFC Fight Night: Vettori vs. Holland', 'UFC 260: Miocic vs. Ngannou', 'UFC Fight Night: Brunson vs. Holland', 'UFC Fight Night: Edwards vs. Muhammad', 'UFC 259: Blachowicz vs. Adesanya', 'UFC Fight Night: Rozenstruik vs. Gane', 'UFC Fight Night: Blaydes vs. Lewis', 'UFC 258: Usman vs. Burns', 'UFC Fight Night: Overeem vs. Volkov', 'UFC 257: Poirier vs. McGregor', 'UFC Fight Night: Chiesa vs. Magny', 'UFC Fight Night: Holloway vs. Kattar', 'UFC Fight Night: Thompson vs. Neal', 'UFC 256: Figueiredo vs. Moreno', 'UFC Fight Night: Hermansson vs. Vettori', 'UFC Fight Night: Smith vs. Clark', 'UFC 255: Figueiredo vs. Perez', 'UFC Fight Night: Felder vs. Dos Anjos', 'UFC Fight Night: Santos vs. Teixeira', 'UFC Fight Night: Hall vs. Silva', 'UFC 254: Khabib vs. Gaethje', 'UFC Fight Night: Ortega vs. The Korean Zombie', 'UFC Fight Night: Moraes vs. Sandhagen', 'UFC Fight Night: Holm vs. Aldana', 'UFC 253: Adesanya vs. Costa', 'UFC Fight Night: Covington vs. Woodley', 'UFC Fight Night: Waterson vs. Hill', 'UFC Fight Night: Overeem vs. Sakai', 'UFC Fight Night: Smith vs. Rakic', 'UFC Fight Night: Munhoz vs. Edgar', 'UFC 252: Miocic vs. Cormier 3', 'UFC Fight Night: Lewis vs. Oleinik', 'UFC Fight Night: Brunson vs. Shahbazya ...

# %%
# remove space after last word in event name in fight_results.csv
fight_results_df['EVENT'] = fight_results_df['EVENT'].str.strip()

# filter fight results and stats based on the filtered event names
filtered_fight_results_df = fight_results_df[fight_results_df['EVENT'].isin(filtered_event_names)]
filtered_fight_stats_df = fight_stats_df[fight_stats_df['EVENT'].isin(filtered_event_names)]
display(filtered_fight_results_df)
display(filtered_fight_stats_df)
# Out:
#                                           EVENT  \
# 733   UFC Fight Night: Cannonier vs. Strickland
# 734   UFC Fight Night: Cannonier vs. Strickland
# 735   UFC Fight Night: Cannonier vs. Strickland
# 736   UFC Fight Night: Cannonier vs. Strickland
# 737   UFC Fight Night: Cannonier vs. Strickland
# ...                                         ...
# 2204               UFC 246: McGregor vs. Cowboy
# 2205               UFC 246: McGregor vs. Cowboy
# 2206               UFC 246: McGregor vs. Cowboy
# 2207               UFC 246: McGregor vs. Cowboy
# 2208               UFC 246: McGregor vs. Cowboy
#
#                                        BOUT OUTCOME             WEIGHTCLASS  \
# 733   Jared Cannonier  vs. Sean Strickland      W/L       Middleweight Bout
# 734   Arman Tsarukyan  vs. Damir Ismagulov      W/L        Lightweight Bout
# 735      Amir Albazi  vs. Alessandro Costa      W/L          Flyweight Bout
# 736         Alex Caceres  vs. Julian Erosa      W/L      Featherweight Bout
# 737            Drew Dober  vs. Bobby Green      W/L        Lightweight Bout
# ...                                     ...     ...                     ...
# 2204          Andre Fili  vs. Sodiq Yusuff      L/W      Featherweight Bout
# 2205        Tim Elliott  vs. Askar Askarov      L/W          Flyweight Bout
# 2206      Drew Dober  vs. Nasrat Haqparast      W/L        Lightweight Bout
# 2207        Aleksa Camur  vs. Justin Ledet      W/L  Light Heavyweight Bout
# 2208           Sabina Mazo  vs. JJ Aldrich      W/L  Women's Flyweight Bout
#
#                      METHOD  ROUND  TIME        TIME FORMAT         REFEREE  \
# 733       Decision - Split       5  5:00  5 Rnd (5-5-5-5-5)       Herb Dean
# 734   Decision - Unanimous       3  5:00      3 Rnd (5-5-5)      Mark Smith
# 735                 KO/TKO       3  2:13      3 Rnd (5-5-5)  Keith Peterson
# 736                 KO/TKO       1  3:04      3 Rnd (5-5-5)       Herb Dean
# 737                 KO/TKO       2  2:45      3 Rnd (5-5-5)  Keith Peterson
# ...                     ...    ...   ...                ...             ...
# 2204  Decision - Unanimous       3  5:00      3 Rnd (5-5-5)   Chris Tognoni
# 2205  Decision - Unanimous       3  5:00      3 Rnd (5-5-5)  Keith Peterson
# 2206                KO/TKO       1  1:10      3 Rnd (5-5-5)      Mark Smith
# 2207  Decision - Unanimous       3  5:00      3 Rnd (5-5-5)       Herb Dean
# 2208      Decision - Split       3  5:00      3 Rnd (5-5-5)   Chris Tognoni
#
#                                                 DETAILS  \
# 733   Derek Cleary 46 - 49.Sal D'amato 49 - 46.Junic...
# 734   Mike Bell 27 - 30.Sal D'amato 27 - 30.Ron McCa...
# 735                          Punch to Head At Distance
# 736                           Kick to Head At Distance
# 737                          Punch to Head At Distance
# ...                                                 ...
# 2204  Chris Lee 28 - 29.Derek Cleary 28 - 29.Adalaid...
# 2205  Mike Bell 28 - 29.Sal D'amato 27 - 30.Dave Hag...
# 2206                         Punch to Head At Distance
# 2207  Derek Cleary 28 - 29.Ron McCarthy 27 - 30.Tony...
# 2208  Junichiro Kamijo 28 - 29.Chris Lee 29 - 28.Ada...
#
#                                                     URL
# 733   http://ufcstats.com/fight-details/4ea48bf2407b...
# 734   http://ufcstats.com/fight-details/ce7744d45a69...
# 735   http://ufcstats.com/fight-details/d95eeba3de7e...
# 736   http://ufcstats.com/fight-details/9c1a2ac64c98...
# 737   http://ufcstats.com/fight-details/c335f44e4f35...
# ...                                                 ...
# 2204  http://ufcstats.com/fight-details/5868c1547896...
# 2205  http://ufcstats.com/fight-details/ff467a5f06a9...
# 2206  http://ufcstats.com/fight-details/63dd38f0dcc2...
# 2207  http://ufcstats.com/fight-details/6087c50c5f95...
# 2208  http://ufcstats.com/fight-details/96fe84d05184...
#
# [1476 rows x 11 columns]
#                                            EVENT  \
# 3596   UFC Fight Night: Cannonier vs. Strickland
# 10835  32 of 116    7 of 8   7 of 9  42 of 129    4 of 4  0 of 0
# 10836   18 of 64  18 of 20   7 of 9   21 of 67  22 of 26  0 of 0
# 10837   11 of 40    2 of 3   2 of 4   14 of 46    1 of 1  0 of 0
# 10838   20 of 47    5 of 5   1 of 1   24 of 49    2 of 4  0 of 0
# 10839   14 of 38    3 of 5   0 of 1   11 of 37    6 of 7  0 of 0
#
# [7244 rows x 19 columns]

# %%
# merge the filtered fight results and stats DataFrames on the relevant columns
merged_df = pd.merge(filtered_fight_results_df, filtered_fight_stats_df, on=['EVENT'])
print(merged_df)
# Out:
#                                            EVENT  \
# 0      UFC Fight Night: Cannonier vs. Strickland
# 1      UFC Fight Night: Cannonier vs. Strickland
# 2      UFC Fight Night: Cannonier vs. Strickland
# 3      UFC Fight Night: Cannonier vs. Strickland
# 4      UFC Fight Night: Cannonier vs. Strickland
# ...                                          ...
# 86229               UFC 246: McGregor vs. Cowboy
# 86230               UFC 246: McGregor vs. Cowboy
# 86231               UFC 246: McGregor vs. Cowboy
# 86232               UFC 246: McGregor vs. Cowboy
# 86233               UFC 246: McGregor vs. Cowboy
#
#                                       BOUT_x OUTCOME             WEIGHTCLASS  \
# 0      Jared Cannonier  vs. Sean Strickland      W/L       Middleweight Bout
# 1      Jared Cannonier  vs. Sean Strickland      W/L       Middleweight Bout
# 2      Jared Cannonier  vs. Sean Strickland      W/L       Middleweight Bout
# 3      Jared Cannonier  vs. Sean Strickland      W/L       Middleweight Bout
# 4      Jared Cannonier  vs. Sean Strickland      W/L       Middleweight Bout
# ...                                      ...     ...                     ...
# 86229           Sabina Mazo  vs. JJ Aldrich      W/L  Women's Flyweight Bout
# 86230           Sabina Mazo  vs. JJ Aldrich      W/L  Women's Flyweight Bout
# 86231           Sabina Mazo  vs. JJ Aldrich      W/L  Women's Flyweight Bout
# 86232           Sabina Mazo  vs. JJ Aldrich      W/L  Women's Flyweight Bout
# 86233           Sabina Mazo  vs. JJ Aldrich      W/L  Women's Flyweight Bout
#
#                   METHOD  ROUND_x  TIME        TIME FORMAT        REFEREE  \
# 0      Decision - Split         5  5:00  5 Rnd (5-5-5-5-5)      Herb Dean
# 1      Decision - Split         5  5:00  5 Rnd (5-5-5-5-5)      Herb Dean
# 2      Decision - Split         5  5:00  5 Rnd (5-5-5-5-5)      Herb Dean
# 3      Decision - Split         5  5:00  5 Rnd (5-5-5-5-5)      Herb Dean
# 4      Decision - Split         5  5:00  5 Rnd (5-5-5-5-5)      Herb Dean
# ...                  ...      ...   ...                ...            ...
# 86229  Decision - Split         3  5:00      3 Rnd (5-5-5)  Chris Tognoni
# 86230  Decision - Split         3  5:00      3 Rnd (5-5-5)  Chris Tognoni
# 86231  Decision - Split         3  5:00      3 Rnd (5-5-5)  Chris Tognoni
# 86232  Decision - Split         3  5:00      3 Rnd (5-5-5)  Chris Tognoni
# 86233  Decision - Split         3  5:00      3 Rnd (5-5-5)  Chris Tognoni
#
#                                                  DETAILS  ... TD % SUB.ATT  \
# 0      Derek Cleary 46 - 49.Sal D'amato 49 - 46.Junic...  ...  ---     0.0
# 1      Derek Cleary 46 - 49.Sal D'amato 49 - 46.Junic...  ...  ---     0.0
# 2      Derek Cleary 46 - 49.Sal D'amato 49 - 46.Junic...  ...  ---     0.0
# 3      Derek Cleary 46 - 49.Sal D'amato 49 - 46.Junic...  ...  ---     0.0
# 4      Derek Cleary 46 - 49.Sal D'amato 49 - 46.Junic...  ...  ---     0.0
# ...                                                  ...  ...  ...     ...
# 86229  Junichiro Kamijo 28 - 29.Chris Lee 29 - 28.Ada...  ...  ---     0.0
# 86230  Junichiro Kamijo 28 - 29.Chris Lee 29 - 28.Ada...  ...  ---     0.0
# 86231  Junichiro Kamijo 28 - 29.Chris Lee 29 - 28.Ada...  ...  ---     0.0
# 86232  Junichiro Kamijo 28 - 29.Chris Lee 29 - 28.Ada...  ...  ---     0.0
# 86233  Junichiro Kamijo 28 - 29.Chris Lee 29 - 28.Ada...  ...  ---     0.0
#
#       REV.  CTRL       HEAD      BODY      LEG   DISTANCE    CLINCH  GROUND
# 0      0.0  0:00    3 of 26    7 of 8   6 of 9   16 of 43    0 of 0  0 of 0
# 1      0.0  0:00    6 of 28  11 of 18  8 of 12   25 of 58    0 of 0  0 of 0
# 2      0.0  0:00   12 of 40  15 of 21   6 of 8   33 of 69    0 of 0  0 of 0
# 3      0.0  0:00   14 of 39  11 of 18   2 of 4   27 of 61    0 of 0  0 of 0
# 4      0.0  0:00   22 of 54  16 of 23   2 of 2   40 of 79    0 of 0  0 of 0
# ...    ...   ...        ...       ...      ...        ...       ...     ...
# 86229  0.0  0:00  32 of 116    7 of 8   7 of 9  42 of 129    4 of 4  0 of 0
# 86230  0.0  2:01   18 of 64  18 of 20   7 of 9   21 of 67  22 of 26  0 of 0
# 86231  0.0  0:00   11 of 40    2 of 3   2 of 4   14 of 46    1 of 1  0 of 0
# 86232  0.0  0:00   20 of 47    5 of 5   1 of 1   24 of 49    2 of 4  0 of 0
# 86233  0.0  0:03   14 of 38    3 of 5   0 of 1   11 of 37    6 of 7  0 of 0
#
# [86234 rows x 29 columns]

# %%
# Split the merged DataFrame into training, validation, and test sets
train_df, temp_df = train_test_split(merged_df, test_size=0.3, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# Display the sizes of the datasets
print(f'Training set size: {len(train_df)}')
print(f'Validation set size: {len(val_df)}')
print(f'Test set size: {len(test_df)}')
# Out:
# Training set size: 60363
# Validation set size: 12935
# Test set size: 12936

# %%
# Save the datasets to new CSV files
train_df.to_csv('ufc_fight_stats_train.csv', index=False)
val_df.to_csv('ufc_fight_stats_val.csv', index=False)
test_df.to_csv('ufc_fight_stats_test.csv', index=False)

# Display a message indicating completion
print('Datasets created and saved successfully.')
# Out:
# Datasets created and saved successfully.
